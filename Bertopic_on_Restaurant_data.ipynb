# %% [markdown]
# <a href="https://colab.research.google.com/github/Theophilusakugre/Restaurant_reviews/blob/main/Bertopic_on_Restaurant_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bertopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bertopic
#   Downloading bertopic-0.14.1-py2.py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.22.4)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.29.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 76.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 11.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.65.0)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.13.1)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.34)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.10.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers>=0.4.1->bertopic)
#   Downloading transformers-4.29.1-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 111.8 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.15.1+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Collecting sentencepiece (from sentence-transformers>=0.4.1->bertopic)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.3 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers>=0.4.1->bertopic)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 73.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.12.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (23.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (16.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 115.0 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp310-cp310-linux_x86_64.whl size=3541455 sha256=66f0d4997c1b62e1d1bd1da02456b75129ee632f313690d9887092ac70cd1ca0
#   Stored in directory: /root/.cache/pip/wheels/dc/52/e3/6c6b60b126b4d5c4370cb5ac071b82950f91649d62d72f7f56
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=e1a7cc146fb96499c8c5f2c8caab01db539d2d930f855feb82e76a8b4c1ab442
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82816 sha256=ec53f2c1f5faa7a6173a906f25dc84b59271391d4363335d4970f221567b9d5f
#   Stored in directory: /root/.cache/pip/wheels/a0/e8/c6/a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55622 sha256=4a6991c37eded2889abde8e39f3c37e74a10b656979fc8288b12b3e1c07faf3b
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: tokenizers, sentencepiece, huggingface-hub, transformers, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
# Successfully installed bertopic-0.14.1 hdbscan-0.8.29 huggingface-hub-0.14.1 pynndescent-0.5.10 sentence-transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.29.1 umap-learn-0.5.3

# %%
import pandas as pd

# %% [markdown]
# # New Section

# %%
df = pd.read_csv('Restaurant_Reviews.tsv', delimiter='\t')

# %%
df.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer, util
from umap import UMAP

# %%
df.columns
# Out:
# Index(['Review', 'Liked'], dtype='object')

# %%
df.Liked.value_counts()
# Out:
# 1    500
# 0    500
# Name: Liked, dtype: int64

# %%
df['len_chac'] = df.Review.str.len()
df.len_chac.describe()
# Out:
# count    1000.000000
# mean       58.315000
# std        32.360052
# min        11.000000
# 25%        33.000000
# 50%        51.000000
# 75%        80.000000
# max       149.000000
# Name: len_chac, dtype: float64

# %%
docs = df.Review.to_list()

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer_model = CountVectorizer(stop_words="english")

# %%
# %%time
model_embedding = SentenceTransformer('all-MiniLM-L6-v2')
corpus_embeddings = model_embedding.encode(docs)
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# CPU times: user 2.86 s, sys: 1.14 s, total: 4 s
# Wall time: 15.9 s

# %%
# %%time
model = BERTopic(
    n_gram_range=(1, 2),
    vectorizer_model=vectorizer_model,
    nr_topics='auto',
    min_topic_size=10,
    seed_topic_list=[
        ["experience", "bad", "good", "nice"],
        ["place", "atmosphere", "toilet", "clean"],
        ["staff", "waitress", "service"],
        ["wait", "time", "long"],
        ["food", "taste"]
    ],
    calculate_probabilities=True).fit(docs, corpus_embeddings)
# Out:
# CPU times: user 11.8 s, sys: 127 ms, total: 11.9 s
# Wall time: 10.7 s

# %%
topics, probabilities = model.transform(docs, corpus_embeddings)

# %%
df_topic_freq = model.get_topic_freq()
topics_count = len(df_topic_freq) - 1
df_topic_freq
# Out:
#     Topic  Count
# 0      -1    346
# 1       0    311
# 2       1     58
# 3       2     58
# 4       3     47
# 5       4     46
# 6       5     42
# 7       6     20
# 8       7     19
# 9       8     17
# 10      9     14
# 11     10     12
# 12     11     10

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id
"],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.08348774539791273,0.09149421957006766,0.12068392232790157,0.22064484973414975,0.5498095649004436],"y":["special  ","helpful  ","super  ","friendly  ","staff  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.10340026392258876,0.11168802519843231,0.11197213167882734,0.19466855227673968,0.42732697987266116],"y":["perfectly  ","best  ","plate  ","steaks  ","steak  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.10056993527325131,0.12133677793577807,0.1214953101090418,0.1214953101090418,0.45112529217080244],"y":["area  ","good  ","homemade  ","pizzas  ","pizza  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.1647964378705327,0.17672045106769715,0.17672045106769715,0.191370552323814,0.191370552323814],"y":["clean  ","bathroom  ","decor  ","shower  ","bathrooms  "],"type":"bar","xaxis":"x12","yaxis":"y12"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gr ...

# %%
reduced_embeddings = UMAP(n_neighbors=10, n_components=2, min_dist=0.0, metric='cosine').fit_transform(corpus_embeddings)
model.visualize_documents(docs, reduced_embeddings=reduced_embeddings)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="91b9696e-d170-4bf3-af12-5c03b60d17a4" class="plotly-graph-div" style="height:750px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91b9696e-d170-4bf3-af12-5c03b60d17a4")) {                    Plotly.newPlot(                        "91b9696e-d170-4bf3-af12-5c03b60d17a4",                        [{"hoverinfo":"text","hovertext":["The only redeeming quality of the restaurant was that it was very inexpensive.","I think this restaurant suffers from not trying hard enough.","But now I was completely grossed out.","This is a great restaurant at the Mandalay Bay.","Any grandmother can make a roasted chicken better than this one.","One of the few places in Phoenix that I would definately go back to again .","I'll take my business dinner dollars elsewhere.","If you are reading this please don't go there.","I work in the hospitality industry in Paradise Valley and have refrained from recommending Cibo any longer.","A good time!","Lordy, the Khao Soi is a dish that is not to be missed for curry lovers!","Our server was fantastic and when he found out the wife loves roasted garlic and bone marrow, he added extra to our meal and another marrow to go!","I have never had such bland food which surprised me considering the article we read focused so much on their spices and flavor.","The food, amazing.","I love that they put their food in nice plastic containers as opposed to cramming it in little paper takeout boxes.","Terrible management.","Now I am getting angry and I want my damn pho.","The kids play area is NASTY!","The chefs were friendly and did a good job.","Bad day or not, I have a very low tolerance for rude customer service people, it is your job to be nice and polite, wash dishes otherwise!!","Worst food/service I've had in a while.","The menu had so much good stuff on it i could not decide!","Love the margaritas, too!","The sergeant pepper beef sandwich with auju sauce is an excellent sandwich as well.","for 40 bucks a head, i really expect better food.","If you're not familiar, check it out.","The food was outstanding and the prices were very reasonable.","The live music on Fridays totally blows.","Left very frustrated.","My gyro was basically lettuce only.","The salad had just the right amount of sauce to not over power the scallop, which was perfectly cooked.","Always a pleasure dealing with him.","She was quite disappointed although some blame needs to be placed at her door.","Bacon is hella salty.","Great food.","The best place to go for a tasty bowl of Pho!","The Veggitarian platter is out of this world!","My girlfriend's veal was very bad.","Very convenient, since we were staying at the MGM!","Fantastic food!","CONCLUSION: Very filling meals.","But then they came back cold.","Nargile - I think you are great.","I was disgusted because I was pretty sure that was human hair.","I had a seriously solid breakfast here.","It was a huge awkward 1.5lb piece of cow that was 3/4ths gristle and fat.","Weird vibe from owners.","Perhaps I caught them on an off night judging by the other reviews, but I'm not inspired to go back.","This place is hands-down one of the best places to eat in the Phoenix metro area.","Google mediocre and I imagine Smashburger will pop up.","I consider this theft.","Nice blanket of moz over top but i feel like this was done to cover up the subpar food.","I love the Pho and the spring rolls oh so yummy you have to try.","I have been here several times in the past, and the experience has always been great.","Update.....went back for a second time and it was still just as amazing","I've lived here since 1979 and this was the first (and last) time I've stepped foot into this place.","If that bug never showed up I would have given a 4 for sure, but on the other side o ...

# %%
# visualize the topic representation of major topics per class:
topics_per_class = model.topics_per_class(docs, classes=df.Liked.to_list())
model.visualize_topics_per_class(topics_per_class, top_n_topics=14)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="858c512a-d051-4779-9c8e-458ef28d4e26" class="plotly-graph-div" style="height:900px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("858c512a-d051-4779-9c8e-458ef28d4e26")) {                    Plotly.newPlot(                        "858c512a-d051-4779-9c8e-458ef28d4e26",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: service, place, food, good, experience","<b>Topic 0</b><br>Words: service, place, good, food, great"],"marker":{"color":"#E69F00"},"name":"0_service_place_food_good","orientation":"h","visible":true,"x":[158,153],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: wont, dont, coming, going, probably","<b>Topic 1</b><br>Words: definitely, soon, ill, coming, wont"],"marker":{"color":"#56B4E9"},"name":"1_wont_coming_dont_soon","orientation":"h","visible":"legendonly","x":[44,14],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 2</b><br>Words: sushi, vegas, buffet, shrimp, place","<b>Topic 2</b><br>Words: vegas, sushi, buffet, breakfast, best"],"marker":{"color":"#009E73"},"name":"2_vegas_sushi_buffet_breakfast","orientation":"h","visible":"legendonly","x":[27,31],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 3</b><br>Words: fries, burger, hot, potato, flat","<b>Topic 3</b><br>Words: potato, butter, delicious, good, bread"],"marker":{"color":"#F0E442"},"name":"3_fries_potato_hot_burger","orientation":"h","visible":"legendonly","x":[18,29],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 4</b><br>Words: minutes, waited, took, wait, food","<b>Topic 4</b><br>Words: seated, greeted, came, wait, fianc"],"marker":{"color":"#D55E00"},"name":"4_minutes_waited_wait_took","orientation":"h","visible":"legendonly","x":[39,7],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 5</b><br>Words: flavor, tasteless, bland, sauce, spicy","<b>Topic 5</b><br>Words: spicy, flavorful, tender, taste, just"],"marker":{"color":"#0072B2"},"name":"5_flavor_spicy_tasteless_bland","orientation":"h","visible":"legendonly","x":[26,16],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 6</b><br>Words: stars, zero, star, deserves, rated","<b>Topic 6</b><br>Words: stars, thumbs, deserves, im, round"],"marker":{"color":"#CC79A7"},"name":"6_stars_zero_deserves_star","orientation":"h","visible":"legendonly","x":[12,8],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 7</b><br>Words: waiter, waitress, bye, tip, friendly","<b>Topic 7</b><br>Words: waitress, friendly, waiter, accomodate, waitresses"],"marker":{"color":"#E69F00"},"name":"7_waitress_waiter_friendly_bye","orientation":"h","visible":"legendonly","x":[10,9],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 8</b><br>Words: staff, friendly, workers, bitches, hi","<b>Topic 8</b><br>Words: staff, friendly, super, special, helpful"],"marker":{"color":"#56B4E9"},"name":"8_staff_friendly_super_helpful","orientation":"h","visible":"legendonly","x":[4,13],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 9</b><br>Words: steak, meat, plate, steakhouse, bloodiest","<b>Topic 9</b><br>Words: steak, steaks, best, perfectly, cooked"],"marker":{"color":"#009E73"},"name":"9_steak_steaks_plate_best","orientation":"h","visible":"legendonly","x":[5,9],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 10</b><br>Words: pizza, doughy, flavorless, arent, chewy","<b>Topic 10</b><br>Words: pizza, homemade, pizzas, area, good"],"marker":{"color":"#F0E442"},"name":"10_pizza_pizzas_homemade_good","orientation":"h","visible":"legendonly","x":[2,10],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 11</b><br>Words: shower, bathrooms, bathroom ...

# %%
# Comment out this line below if you decided to use the "propbabilities" strategy
new_topics = model.reduce_outliers(docs, topics, strategy="c-tf-idf")


# Reduce outliers using the `probabilities` strategy (Uncomment to use this)
#new_topics = model.reduce_outliers(docs, topics, probabilities=probabilities, strategy="probabilities")

# %%
# This line is to update the model with the latest topic assignment 
model.update_topics(docs, topics=new_topics, vectorizer_model=vectorizer_model)

# %%
model.get_topic_freq()
# Out:
#     Topic  Count
# 0       0    433
# 1       2     89
# 2       3     81
# 3       5     74
# 4       1     73
# 5       4     65
# 6       7     34
# 7       9     33
# 8      10     29
# 9       8     27
# 10     11     26
# 11      6     24
# 12     -1     12

# %%
new_topics = model.reduce_outliers(docs, topics, strategy="c-tf-idf")

# %%
# Reduce outliers using the `probabilities` strategy
#new_topics = model.reduce_outliers(docs, topics, probabilities=probabilities, strategy="probabilities")
#new_topics = model.reduce_outliers(docs, topics, strategy="embeddings", embeddings=corpus_embeddings)

model.update_topics(docs, topics=new_topics, vectorizer_model=vectorizer_model)

# %%
model.get_topic_freq()
# Out:
#     Topic  Count
# 0       0    425
# 1       2     90
# 2       3     81
# 3       5     76
# 4       1     75
# 5       4     66
# 6       7     36
# 7       9     34
# 8      10     31
# 9       8     27
# 10     11     27
# 11      6     24
# 12     -1      8

# %%
model.visualize_barchart(top_n_topics=19)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4be03a0a-65e4-4f45-8bc4-bbbd5e0ba7e8" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4be03a0a-65e4-4f45-8bc4-bbbd5e0ba7e8")) {                    Plotly.newPlot(                        "4be03a0a-65e4-4f45-8bc4-bbbd5e0ba7e8",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.04222920229140016,0.061789570694194995,0.07210262230213302,0.07639113145158173,0.07981210394687215],"y":["great  ","good  ","food  ","place  ","service  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.11328793266135337,0.1134405577046062,0.12314855936786655,0.13029518603928436,0.17492717434424296],"y":["coming  ","think  ","going  ","dont  ","wont  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.051413337191363206,0.05748376016807373,0.060580666219783384,0.08354667293596521,0.10569159390653986],"y":["quality  ","time  ","buffet  ","sushi  ","vegas  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.054283563124704906,0.054283563124704906,0.05897225904537061,0.061861503246453,0.07670050637304884],"y":["dishes  ","hot  ","taste  ","ordered  ","delicious  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.0673304983435597,0.08258504611375335,0.08523869731146981,0.09744736913272913,0.14583808087544922],"y":["food  ","took  ","wait  ","waited  ","minutes  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.050096806585962106,0.06679574211461614,0.07076036905655685,0.07324753279301083,0.09324509790615418],"y":["perfect  ","sauce  ","spicy  ","bland  ","flavor  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.13375630470720198,0.13375630470720198,0.15978500664896683,0.1678793019634269,0.42140144055988216],"y":["deserves  ","star  ","zero  ","thumbs  ","stars  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.10871006419303425,0.1166029963657999,0.12326527918108925,0.157316099868773,0.18263290784429756],"y":["rude  ","management  ","friendly  ","waiter  ","waitress  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.08154319076209567,0.09850971089922309,0.14102659695593367,0.1677199026695395,0.39625914587419364],"y":["super  ","treated  ","special  ","friendly  ","staff  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.07002108640566403,0.07438488374022967,0.09336144854088535,0.1339116628654673,0.22202107542703742],"y":["damn  ","perfectly  ","steaks  ","best  ","steak  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0
"],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.08482093697112363,0.09467167021483776,0.10448824443974163,0.1088898440717377,0.11284194811057836],"y":["outside  ","decor  ","inside  ","nice  ","just  "],"type":"bar","xaxis":"x12","yaxis":"y12"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f ...

# %%
# To manually select topics to merge
topics_to_merge = [
    [0, 13]
]
model.merge_topics(docs, topics_to_merge)

# %%
# Manualy Set the Topics's Label
topic_labels_dict = {
    0: "Environment",
    1: "Service",
    2: "Food & Taste",
    3: "Overall Experience",
    4: "Food & Taste",
    5: "Waiting Time",
    6: "Fries and Potato",
    7: "Steak",
    8: "Price",
    9: "Food & Taste",
    10: "Pizza",
    11: "Staff",
    12: "Rating",
    13: "Staff",
    14: "Staff"
}
model.set_topic_labels(topic_labels_dict)

# %%
# Optimizing Label

from transformers import pipeline
classifier = pipeline("zero-shot-classification", model="facebook/bart-l arge-mnli")

# A selected topic representation
# 'god jesus atheists atheism belief atheist believe exist beliefs existence'
sequence_to_classify =  " ".join([word for word, _ in topic_model.get_topic(1)])

# Our set of potential topic labels
candidate_labels = ['cooking', 'dancing', 'religion']
classifier(sequence_to_classify, candidate_labels)
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py in _get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     628                 # Load from local folder or from cache or download from model Hub and cache
# --> 629                 resolved_config_file = cached_file(
#     630                     pretrained_model_name_or_path,
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash)
#     416         # Load from URL or cache if already cached
# --> 417         resolved_file = hf_hub_download(
#     418             path_or_repo_id,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     111             if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 112                 validate_repo_id(arg_value)
#     113
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in validate_repo_id(repo_id)
#     165     if not REPO_ID_REGEX.match(repo_id):
# --> 166         raise HFValidationError(
#     167             "Repo id must use alphanumeric chars or '-', '_', '.', '--' and '..' are"
#
# HFValidationError: Repo id must use alphanumeric chars or '-', '_', '.', '--' and '..' are forbidden, '-' and '.' cannot start or end the name, max length is 96: 'facebook/bart-l arge-mnli'.
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-34-8f763738fbee> in <cell line: 4>()
#       2
#       3 from transformers import pipeline
# ----> 4 classifier = pipeline("zero-shot-classification", model="facebook/bart-l arge-mnli")
#       5
#       6 # A selected topic representation
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, use_auth_token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     703         hub_kwargs["_commit_hash"] = config._commit_hash
#     704     elif config is None and isinstance(model, str):
# --> 705         config = AutoConfig.from_pretrained(model, _from_pipeline=task, **hub_kwargs, **model_kwargs)
#     706         hub_kwargs["_commit_hash"] = config._commit_hash
#     707
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     926         kwargs["name_or_path"] = pretrained_model_name_or_path
#     927         trust_remote_code = kwargs.pop("trust_remote_code", False)
# --> 928         config_dict, unused_kwargs = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     929         if "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]:
#     930             if not trust_remote_code:
#
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py in get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     572         original_kwargs = copy.deepcopy(kwargs)
#     573         # Get config dict associated with the base config file
# --> 574         config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     575         if "_commit_hash" in config_dict:
#     576             original_kwargs["_commit_hash"] = config_dict["_commit_hash"]
#
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py in _get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     648             except Exception:
#     649                 # For any other exception, we throw a generic error.
# --> 650                 raise EnvironmentError(
#     651                     f"Can't load the configuration of '{pretrained_model_name_or_path}'. If you were trying to load it"
#     652                     " from 'https://huggingface.co/models', make sure you don't have a local directory with the same"
#
# OSError: Can't load the configuration of 'facebook/bart-l arge-mnli'. If you were trying to load it from 'https://huggingface.co/models', make sure you don't have a local directory with the same name. Otherwise, make sure 'facebook/bart-l arge-mnli' is the correct path to a directory containing a config.json file

# %%
topic_distr, topic_token_distr = model.approximate_distribution(docs, calculate_tokens=True)

# %%
doc_id = 41
model.visualize_approximate_distribution(docs[doc_id], topic_token_distr[doc_id])
# Out:
# <style type="text/css">
# #T_51aa7_row0_col0, #T_51aa7_row0_col8, #T_51aa7_row0_col9, #T_51aa7_row0_col10, #T_51aa7_row0_col11, #T_51aa7_row0_col12, #T_51aa7_row0_col13, #T_51aa7_row1_col0, #T_51aa7_row1_col1, #T_51aa7_row1_col2, #T_51aa7_row1_col3, #T_51aa7_row1_col8, #T_51aa7_row1_col9, #T_51aa7_row1_col10, #T_51aa7_row1_col11, #T_51aa7_row1_col12, #T_51aa7_row1_col13, #T_51aa7_row2_col0, #T_51aa7_row2_col1, #T_51aa7_row2_col2, #T_51aa7_row2_col3, #T_51aa7_row2_col8, #T_51aa7_row2_col9, #T_51aa7_row2_col10, #T_51aa7_row2_col11, #T_51aa7_row2_col12, #T_51aa7_row2_col13 {
#   background-color: #f7fbff;
#   color: #000000;
#   color: white;
#   background-color: white;
# }
# #T_51aa7_row0_col1 {
#   background-color: #cee0f2;
#   color: #000000;
#   color: black;
# }
# #T_51aa7_row0_col2 {
#   background-color: #8dc1dd;
#   color: #000000;
#   color: black;
# }
# #T_51aa7_row0_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
#   color: black;
# }
# #T_51aa7_row0_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   color: black;
# }
# #T_51aa7_row0_col5 {
#   background-color: #1966ad;
#   color: #f1f1f1;
#   color: black;
# }
# #T_51aa7_row0_col6 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
#   color: black;
# }
# #T_51aa7_row0_col7 {
#   background-color: #9dcae1;
#   color: #000000;
#   color: black;
# }
# #T_51aa7_row1_col4, #T_51aa7_row1_col5, #T_51aa7_row1_col6, #T_51aa7_row1_col7 {
#   background-color: #caddf0;
#   color: #000000;
#   color: black;
# }
# #T_51aa7_row2_col4, #T_51aa7_row2_col5, #T_51aa7_row2_col6, #T_51aa7_row2_col7 {
#   background-color: #d9e8f5;
#   color: #000000;
#   color: black;
# }
# </style>
# <table id="T_51aa7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51aa7_level0_col0" class="col_heading level0 col0" >There</th>
#       <th id="T_51aa7_level0_col1" class="col_heading level0 col1" >is </th>
#       <th id="T_51aa7_level0_col2" class="col_heading level0 col2" >not  </th>
#       <th id="T_51aa7_level0_col3" class="col_heading level0 col3" >deal   </th>
#       <th id="T_51aa7_level0_col4" class="col_heading level0 col4" >good    </th>
#       <th id="T_51aa7_level0_col5" class="col_heading level0 col5" >enough     </th>
#       <th id="T_51aa7_level0_col6" class="col_heading level0 col6" >that      </th>
#       <th id="T_51aa7_level0_col7" class="col_heading level0 col7" >would       </th>
#       <th id="T_51aa7_level0_col8" class="col_heading level0 col8" >drag        </th>
#       <th id="T_51aa7_level0_col9" class="col_heading level0 col9" >me         </th>
#       <th id="T_51aa7_level0_col10" class="col_heading level0 col10" >into          </th>
#       <th id="T_51aa7_level0_col11" class="col_heading level0 col11" >that           </th>
#       <th id="T_51aa7_level0_col12" class="col_heading level0 col12" >establishment            </th>
#       <th id="T_51aa7_level0_col13" class="col_heading level0 col13" >again             </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51aa7_level0_row0" class="row_heading level0 row0" >0_service_place_food_good</th>
#       <td id="T_51aa7_row0_col0" class="data row0 col0" >0.000</td>
#       <td id="T_51aa7_row0_col1" class="data row0 col1" >0.154</td>
#       <td id="T_51aa7_row0_col2" class="data row0 col2" >0.308</td>
#       <td id="T_51aa7_row0_col3" class="data row0 col3" >0.462</td>
#       <td id="T_51aa7_row0_col4" class="data row0 col4" >0.740</td>
#       <td id="T_51aa7_row0_col5" class="data row0 col5" >0.586</td>
#       <td id="T_51aa7_row0_col6" class="data row0 col6" >0.432</td>
#       <td id="T_51aa7_row0_col7" class="data row0 col7" >0.278</td>
#       <td id="T_51aa7_row0_col8" class="data row0 col8" >0.000</td>
#       <td id="T_51aa7_row0_col9" class="data row0 col9" >0.000</td>
#       <td id="T_51aa7_row0_col10" class="data row0 col10" >0.000</td>
#       <td id="T_51aa7_row0_col11" class="data row0 col11" >0.000</td>
#       <td id="T_51aa7_row0_col12" class="data row0 col12" >0.000</td>
#       <td id="T_51aa7_row0_col13" class="data row0 col13" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_51aa7_level0_row1" class="row_heading level0 row1" >2_delicious_ordered_taste_hot</th>
#       <td id="T_51aa7_row1_col0" class="data row1 col0" >0.000</td>
#       <td id="T_51aa7_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_51aa7_row1_col2" class="data row1 col2" >0.000</td>
#       <td id="T_51aa7_row1_col3" class="data row1 col3" >0.000</td>
#       <td id="T_51aa7_row1_col4" class="data row1 col4" >0.173</td>
#       <td id="T_51aa7_row1_col5" class="data row1 col5" >0.173</td>
#       <td id="T_51aa7_row1_col6" class="data row1 col6" >0.173</td>
#       <td id="T_51aa7_row1_col7" class="data row1 col7" >0.173</td>
#       <td id="T_51aa7_row1_col8" class="data row1 col8" >0.000</td>
#       <td id="T_51aa7_row1_col9" class="data row1 col9" >0.000</td>
#       <td id="T_51aa7_row1_col10" class="data row1 col10" >0.000</td>
#       <td id="T_51aa7_row1_col11" class="data row1 col11" >0.000</td>
#       <td id="T_51aa7_row1_col12" class="data row1 col12" >0.000</td>
#       <td id="T_51aa7_row1_col13" class="data row1 col13" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_51aa7_level0_row2" class="row_heading level0 row2" >8_pizza_menu_tasted_amazing</th>
#       <td id="T_51aa7_row2_col0" class="data row2 col0" >0.000</td>
#       <td id="T_51aa7_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_51aa7_row2_col2" class="data row2 col2" >0.000</td>
#       <td id="T_51aa7_row2_col3" class="data row2 col3" >0.000</td>
#       <td id="T_51aa7_row2_col4" class="data row2 col4" >0.112</td>
#       <td id="T_51aa7_row2_col5" class="data row2 col5" >0.112</td>
#       <td id="T_51aa7_row2_col6" class="data row2 col6" >0.112</td>
#       <td id="T_51aa7_row2_col7" class="data row2 col7" >0.112</td>
#       <td id="T_51aa7_row2_col8" class="data row2 col8" >0.000</td>
#       <td id="T_51aa7_row2_col9" class="data row2 col9" >0.000</td>
#       <td id="T_51aa7_row2_col10" class="data row2 col10" >0.000</td>
#       <td id="T_51aa7_row2_col11" class="data row2 col11" >0.000</td>
#       <td id="T_51aa7_row2_col12" class="data row2 col12" >0.000</td>
#       <td id="T_51aa7_row2_col13" class="data row2 col13" >0.000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# To visualize the topic distributions in a document
model.visualize_distribution(topic_distr[doc_id], custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="710af855-185d-42a1-a3b9-371c01e1d339" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("710af855-185d-42a1-a3b9-371c01e1d339")) {                    Plotly.newPlot(                        "710af855-185d-42a1-a3b9-371c01e1d339",                        [{"marker":{"color":"#C8D2D7","line":{"color":"#6E8484","width":1}},"orientation":"h","x":[0.7214503120947173,0.16906859882935285,0.10948108907592972],"y":["Environment","Food & Taste","Price"],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks": ...

# %%
# To visualize the topic distributions in a document
model.visualize_distribution(topic_distr[doc_id])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c234061d-69af-4166-86ff-62397a33946b" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c234061d-69af-4166-86ff-62397a33946b")) {                    Plotly.newPlot(                        "c234061d-69af-4166-86ff-62397a33946b",                        [{"marker":{"color":"#C8D2D7","line":{"color":"#6E8484","width":1}},"orientation":"h","x":[0.7214503120947173,0.16906859882935285,0.10948108907592972],"y":["<b>Topic 0</b>: service_place_food_good_...","<b>Topic 2</b>: delicious_ordered_taste_...","<b>Topic 8</b>: pizza_menu_tasted_amazin..."],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"typ ...

# %%
# Under the topic
model.get_topic(3)[:10]
# Out:
# [('flavor', 0.09324509790615418),
#  ('bland', 0.07324753279301083),
#  ('spicy', 0.07076036905655685),
#  ('sauce', 0.06679574211461614),
#  ('perfect', 0.050096806585962106),
#  ('tasteless', 0.049478879899822116),
#  ('taste', 0.04662254895307709),
#  ('fresh', 0.04564629103185244),
#  ('cold', 0.042915739028784566),
#  ('vegetables', 0.041588281622758023)]

# %%
df['topic'] = model.topics_

# %%
df['topic_label'] = df.topic.map(topic_labels_dict)

# %%
df.to_csv('reviews_clustered.csv', index=False)

# %%
df
# Out:
#                                                 Review  Liked  len_chac  \
# 0                             Wow... Loved this place.      1        24
# 1                                   Crust is not good.      0        18
# 2            Not tasty and the texture was just nasty.      0        41
# 3    Stopped by during the late May bank holiday of...      1        87
# 4    The selection on the menu was great and so wer...      1        59
# ..                                                 ...    ...       ...
# 995  I think food should have flavor and texture an...      0        66
# 996                           Appetite instantly gone.      0        24
# 997  Overall I was not impressed and would not go b...      0        50
# 998  The whole experience was underwhelming, and I ...      0        91
# 999  Then, as if I hadn't wasted enough of my life ...      0       134
#
#      topic         topic_label
# 0        0         Environment
# 1        0         Environment
# 2        3  Overall Experience
# 3        9        Food & Taste
# 4        0         Environment
# ..     ...                 ...
# 995      3  Overall Experience
# 996      4        Food & Taste
# 997      0         Environment
# 998      1             Service
# 999      5        Waiting Time
#
# [1000 rows x 5 columns]

# %%
df.topic_label.unique()
# Out:
# array(['Environment', 'Overall Experience', 'Food & Taste', 'Steak',
#        'Fries and Potato', 'Pizza', nan, 'Service', 'Waiting Time',
#        'Staff', 'Price'], dtype=object)

# %%
df[df['topic_label']=='Environment']
# Out:
#                                                 Review  Liked  len_chac  \
# 0                             Wow... Loved this place.      1        24
# 1                                   Crust is not good.      0        18
# 4    The selection on the menu was great and so wer...      1        59
# 9                                       A great touch.      1        14
# 10                            Service was very prompt.      1        24
# ..                                                 ...    ...       ...
# 988  It really is impressive that the place hasn't ...      0        58
# 989  I would avoid this place if you are staying in...      0        58
# 993            the presentation of the food was awful.      0        39
# 994           I can't tell you how disappointed I was.      0        40
# 997  Overall I was not impressed and would not go b...      0        50
#
#      topic  topic_label
# 0        0  Environment
# 1        0  Environment
# 4        0  Environment
# 9        0  Environment
# 10       0  Environment
# ..     ...          ...
# 988      0  Environment
# 989      0  Environment
# 993      0  Environment
# 994      0  Environment
# 997      0  Environment
#
# [425 rows x 5 columns]

# %%
df[df['topic_label']=='Price']
# Out:
#                                                 Review  Liked  len_chac  \
# 139  My drink was never empty and he made some real...      1        72
# 173  Lordy, the Khao Soi is a dish that is not to b...      1        72
# 174  Everything on the menu is terrific and we were...      1       127
# 254  Now the pizza itself was good the peanut sauce...      1        62
# 284  I would definitely recommend the wings as well...      1        60
# 285                            Great Pizza and Salads!      1        23
# 297  I love the fact that everything on their menu ...      1        58
# 330  The servers are not pleasant to deal with and ...      0        88
# 397  Kids pizza is always a hit too with lots of gr...      1        83
# 426  This is some seriously good pizza and I'm an e...      1        76
# 476                   We enjoy their pizza and brunch.      1        32
# 494  Their daily specials are always a hit with my ...      1        52
# 510  I don't each much pasta, but I love the homema...      1        88
# 540  I had the opportunity today to sample your ama...      1        58
# 575  The pizza tasted old, super chewy in not a goo...      0        52
# 589                       The kids play area is NASTY!      0        28
# 615        The cow tongue and cheek tacos are amazing.      1        43
# 654            The patio seating was very comfortable.      1        39
# 660  I personally love the hummus, pita, baklava, f...      1       114
# 677     The plantains were the worst I've ever tasted.      0        46
# 714  I loved the grilled pizza, reminded me of legi...      1        62
# 715  Only Pros : Large seating area/ Nice bar area/...      1       118
# 720                      Cute, quaint, simple, honest.      1        29
# 728           The Han Nan Chicken was also very tasty.      1        40
# 747  I always order from the vegetarian menu during...      1       104
# 765                                  Tasted like dirt.      0        17
# 848  To my disbelief, each dish qualified as the wo...      0        92
# 865  They have a plethora of salads and sandwiches,...      1        98
# 879  Now the burgers aren't as good, the pizza whic...      0        92
# 896                     The pizza selections are good.      1        30
# 968  We've have gotten a much better service from t...      0       122
#
#      topic topic_label
# 139      8       Price
# 173      8       Price
# 174      8       Price
# 254      8       Price
# 284      8       Price
# 285      8       Price
# 297      8       Price
# 330      8       Price
# 397      8       Price
# 426      8       Price
# 476      8       Price
# 494      8       Price
# 510      8       Price
# 540      8       Price
# 575      8       Price
# 589      8       Price
# 615      8       Price
# 654      8       Price
# 660      8       Price
# 677      8       Price
# 714      8       Price
# 715      8       Price
# 720      8       Price
# 728      8       Price
# 747      8       Price
# 765      8       Price
# 848      8       Price
# 865      8       Price
# 879      8       Price
# 896      8       Price
# 968      8       Price
